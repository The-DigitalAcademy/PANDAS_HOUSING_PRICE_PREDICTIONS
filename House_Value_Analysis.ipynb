# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing_clean.csv')
df
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88                  41          880
# 1               1    -122.22     37.86                  21         7099
# 2               2    -122.24     37.85                  52         1467
# 3               3    -122.25     37.85                  52         1274
# 4               4    -122.25     37.85                  52         1627
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48                  25         1665
# 20636       20636    -121.21     39.49                  18          697
# 20637       20637    -121.22     39.43                  17         2254
# 20638       20638    -121.32     39.43                  18         1860
# 20639       20639    -121.24     39.37                  16         2785
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20640 non-null  int64
#  1   longitude           20640 non-null  float64
#  2   latitude            20640 non-null  float64
#  3   housing_median_age  20640 non-null  int64
#  4   total_rooms         20640 non-null  int64
#  5   total_bedrooms      20640 non-null  int64
#  6   population          20640 non-null  int64
#  7   households          20640 non-null  int64
#  8   median_income       20640 non-null  float64
#  9   median_house_value  20640 non-null  float64
#  10  ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(6), object(1)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0     longitude      latitude  housing_median_age  \
# count  20640.000000  20640.000000  20640.000000        20640.000000
# mean   10319.500000   -119.569704     35.631861           28.639486
# std     5958.399114      2.003532      2.135952           12.585558
# min        0.000000   -124.350000     32.540000            1.000000
# 25%     5159.750000   -121.800000     33.930000           18.000000
# 50%    10319.500000   -118.490000     34.260000           29.000000
# 75%    15479.250000   -118.010000     37.710000           37.000000
# max    20639.000000   -114.310000     41.950000           52.000000
#
#         total_rooms  total_bedrooms    population    households  \
# count  20640.000000    20640.000000  20640.000000  20640.000000
# mean    2635.763081      537.861822   1425.476744    499.539680
# std     2181.615252      419.266601   1132.462122    382.329753
# min        2.000000        1.000000      3.000000      1.000000
# ...

# %%
df.corr()
# Out:
# /var/folders/78/_y27g9w55d15tg1plv7v95540000gq/T/ipykernel_18311/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Unnamed: 0  longitude  latitude  housing_median_age  \
# Unnamed: 0            1.000000  -0.113254  0.081062           -0.181132
# longitude            -0.113254   1.000000 -0.924664           -0.108197
# latitude              0.081062  -0.924664  1.000000            0.011173
# housing_median_age   -0.181132  -0.108197  0.011173            1.000000
# total_rooms           0.061896   0.044568 -0.036100           -0.361262
# total_bedrooms        0.031926   0.069259 -0.066657           -0.318999
# population            0.024880   0.099773 -0.108785           -0.296244
# households            0.030186   0.055310 -0.071035           -0.302916
# ...

# %%
num_var = ['longitude',	'latitude',	'housing_median_age',	'total_rooms','total_bedrooms',	'population',	'households',	'median_income',	'median_house_value']

plt.figure(figsize=(25,25))
# Calculate the number of rows and columns for the subplots
num_rows = (len(num_var) + 3) // 4 
num_cols = 4
for i, var in enumerate(num_var):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.distplot(df[var], bins=20)
    plt.title(var)  

plt.tight_layout()
plt.show()
# Out:
# /var/folders/78/_y27g9w55d15tg1plv7v95540000gq/T/ipykernel_18311/2841191122.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[var], bins=20)
# /var/folders/78/_y27g9w55d15tg1plv7v95540000gq/T/ipykernel_18311/2841191122.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Calculate the average house value for each ocean proximity category
avg_house_values = df.groupby('ocean_proximity')['median_house_value'].mean()

# Calculate bubble size based on the average house value (you might need to adjust the scaling factor)
bubble_sizes = avg_house_values / 1000  # Adjust the scaling factor for appropriate bubble sizes

# Plotting the bubble chart
plt.figure(figsize=(10, 6))
plt.scatter(
    avg_house_values.index,
    avg_house_values,
    s=bubble_sizes,
    alpha=0.7,
    c=avg_house_values,
    cmap='viridis'
)

# Adding labels and title
plt.xlabel('Ocean Proximity')
plt.ylabel('Average House Value')
plt.title('Average Housing Values by Ocean Proximity')
plt.colorbar(label='Average House Value')

# Adjust layout
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
avg_values = df.groupby('ocean_proximity')[['median_house_value', 'housing_median_age']].mean()

ocean_proximities = avg_values.index
avg_house_values = avg_values['median_house_value']
avg_house_age = avg_values['housing_median_age']

# Creating the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(
    avg_house_age,
    avg_house_values,
    s=100,  # Marker size
    c='pink',  # Marker color
    alpha=0.7
)

# Adding labels and title
plt.xlabel('Median House Age')
plt.ylabel('Average House Value')
plt.title('Ocean Proximity Impact on Housing Value and Median House Age')

# Adding data labels for each point
for i, prox in enumerate(ocean_proximities):
    plt.annotate(prox, (avg_house_age[i], avg_house_values[i]), textcoords="offset points", xytext=(0, 10), ha='center')

# Show the plot
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
avg_values = df.groupby('ocean_proximity')[['median_house_value', 'total_bedrooms']].mean()

ocean_proximities = avg_values.index
avg_house_values = avg_values['median_house_value']
avg_total_bedrooms = avg_values['total_bedrooms']

plt.figure(figsize=(10, 6))
plt.scatter(
    avg_total_bedrooms,
    avg_house_values,
    s=100,  # Marker size
    c='purple',  # Marker color
    alpha=0.7
)


plt.xlabel('Average Total Bedrooms')
plt.ylabel('Average House Value')
plt.title('Analysis of Housing')

for i, prox in enumerate(ocean_proximities):
    plt.annotate(prox, (avg_total_bedrooms[i], avg_house_values[i]), textcoords="offset points", xytext=(0, 10), ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 6))
plt.scatter(df['housing_median_age'],df['total_bedrooms'], alpha=0.5)

plt.xlabel('Total Bedrooms')
plt.ylabel('Housing Median Age')
plt.title('Relationship Between Number of Bedrooms and Housing Age')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 6))
plt.scatter( df['housing_median_age'],df['population'], alpha=0.5)

plt.xlabel('Population')
plt.ylabel('Housing Median Age')
plt.title('Relationship Between Population and Median House Age')


plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(10, 6))

sns.barplot(x='ocean_proximity', y='median_house_value', data=df, ax=ax1, color='turquoise')

ax1.set_xlabel('Ocean Proximity')
ax1.set_ylabel('Median House Value', color='turquoise')
ax1.tick_params(axis='y', labelcolor='turquoise')
ax1.set_title('House Value and Income by Ocean Proximity')

ax2 = ax1.twinx()

sns.lineplot(x='ocean_proximity', y='median_income', data=df, ax=ax2, color='lightpink')

ax2.set_ylabel('Median Income', color='lightpink')
ax2.tick_params(axis='y', labelcolor='lightpink')

plt.tight_layout()

plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(10, 6))

sns.barplot(x='ocean_proximity', y='population', data=df, ax=ax1, color='lightpink')

ax1.set_xlabel('Ocean Proximity')
ax1.set_ylabel('Average Population', color='lightpink')
ax1.tick_params(axis='y', labelcolor='lightpink')
ax1.set_title('Comparison of Population and Households by Ocean Proximity')

ax2 = ax1.twinx()

sns.lineplot(x='ocean_proximity', y='households', data=df, ax=ax2, color='turquoise')

ax2.set_ylabel('Avg. Households', color='turquoise')
ax2.tick_params(axis='y', labelcolor='turquoise')

plt.tight_layout()

ax1.grid(False)  # Removing grid lines from the first axis
ax2.grid(False) 
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(10, 6))

# Sorting DataFrame by median_house_value in descending order
df_sorted = df.sort_values(by='median_house_value', ascending=False)

sns.barplot(x='ocean_proximity', y='median_house_value', data=df_sorted, ax=ax1, color='turquoise', linewidth=0)

ax1.set_xlabel('Ocean Proximity')
ax1.set_ylabel('Median House Value', color='turquoise')
ax1.tick_params(axis='y', labelcolor='turquoise')
ax1.set_title('House Value and Income by Ocean Proximity')

ax2 = ax1.twinx()

sns.lineplot(x='ocean_proximity', y='median_income', data=df_sorted, ax=ax2, color='lightpink')

ax2.set_ylabel('Median Income', color='lightpink')
ax2.tick_params(axis='y', labelcolor='lightpink')

ax1.grid(False)  # Removing grid lines from the first axis
ax2.grid(False)  # Removing grid lines from the second axis

plt.tight_layout()

plt.xticks(rotation=45)
plt.show()
